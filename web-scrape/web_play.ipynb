# %%
from  web_fetch_def import fetch_fnc

# %%
fetch_fnc("https://duckduckgo.com/html/?q=stock+vfiax&ia=web",{"result__url","result__snippet","result__title"})
# Out:
# ---------------------------------------------------------------------------
# NameError                                 Traceback (most recent call last)
# <ipython-input-2-a7cf344d98ae> in <module>()
# ----> 1 fetch_fnc("https://duckduckgo.com/html/?q=stock+vfiax&ia=web",{"result__url","result__snippet","result__title"})
#
# ~/Dropbox/ipynb/daily/web_fetch_def.py in fetch_fnc(url, cl)
#      11     page.status_code
#      12     soup = BeautifulSoup(page.content, 'html.parser')
# ---> 13     f.write(unicode(url))
#      14     TBLRoll=soup.find_all(class_=cl)
#      15     for each in TBLRoll:
#
# NameError: name 'unicode' is not defined

# %%
fetch_fnc("https://duckduckgo.com/html/?q=oncology+tutorial&ia=web",{"result__url","result__snippet","result__title"})

# %%
fetch_fnc("https://duckduckgo.com/html/?q=cdisc+tutorial&ia=web",{"result__url","result__snippet","result__title"})

# %%
fetch_fnc("https://duckduckgo.com/html/?q=icd+tutorial&ia=web",{"result__url","result__snippet","result__title"})

# %%
fetch_fnc("https://duckduckgo.com/html/?q=cdash+tutorial&ia=web",{"result__url","result__snippet","result__title"})

# %%
fetch_fnc("http://www.crf.org/crf/news-and-events",{"item-page news_events","result__snippet","result__title"})

# %%
fetch_fnc("http://www.zeroarc.com/features",{"tab-content","result__snippet","result__title"})

# %%
fetch_fnc("http://www.ocregister.com",{"article-info","result__title"})

# %%
fetch_fnc("https://duckduckgo.com/html/?q=Kaplan+Meier+estimate&ia=web",{"result__url","result__snippet","result__title"})

# %%
fetch_fnc("http://www.ocregister.com/business",{"article-info","result__title"})

# %%
# %load web_fetch_work.py
from  web_fetch_def import fetch_fnc
fetch_fnc("https://duckduckgo.com/html/?q=stock+vfiax&ia=web",{"result__url","result__snippet","result__title"})
fetch_fnc("https://duckduckgo.com/html/?q=stock+vig&ia=web",{"result__url","result__snippet","result__title"})
fetch_fnc("https://duckduckgo.com/html/?q=stock+rxdx&ia=web",{"result__url","result__snippet","result__title"})
fetch_fnc("https://duckduckgo.com/html/?q=gilead+gild&ia=web",{"result__url","result__snippet","result__title"})
fetch_fnc("https://duckduckgo.com/html/?q=cldx&ia=web",{"result__url","result__snippet","result__title"})
fetch_fnc("https://duckduckgo.com/html/?q=stock+ardo&ia=web",{"result__url","result__snippet","result__title"})
fetch_fnc("https://duckduckgo.com/html/?q=unitedhealth+UNH&ia=web",{"result__url","result__snippet","result__title"})
fetch_fnc("https://duckduckgo.com/html/?q=biotech&ia=web",{"result__url","result__snippet","result__title"})
fetch_fnc("https://duckduckgo.com/html/?q=broadcom+BRCM&ia=web",{"result__url","result__snippet","result__title"})
fetch_fnc("https://duckduckgo.com/html/?q=optum&ia=web",{"result__url","result__snippet","result__title"})
fetch_fnc("https://duckduckgo.com/html/?q=cdisc&ia=web",{"result__url","result__snippet","result__title"})
fetch_fnc("https://duckduckgo.com/html/?q=dmhc+encounter&ia=web",{"result__url","result__snippet","result__title"})
fetch_fnc("https://duckduckgo.com/html/?q=cms+encounter&ia=web",{"result__url","result__snippet","result__title"})
fetch_fnc("https://duckduckgo.com/html/?q=hedis&ia=web",{"result__url","result__snippet","result__title"})
fetch_fnc("https://duckduckgo.com/html/?q=ncqa&ia=web",{"result__url","result__snippet","result__title"})
fetch_fnc("https://duckduckgo.com/html/?q=fda&ia=web",{"result__url","result__snippet","result__title"})
fetch_fnc("https://duckduckgo.com/html/?q=trans+union+edi+clearing+house&ia=web",{"result__url","result__snippet","result__title"})
fetch_fnc("https://duckduckgo.com/html/?q=payer+edi+clearing+house&ia=web",{"result__url","result__snippet","result__title"})
fetch_fnc("https://duckduckgo.com/html/?q=837+x12&ia=web",{"result__url","result__snippet","result__title"})
fetch_fnc("https://duckduckgo.com/html/?q=ub92&ia=web",{"result__url","result__snippet","result__title"})
fetch_fnc("https://duckduckgo.com/html/?q=nppes+npi&ia=web",{"result__url","result__snippet","result__title"})
# Out:
# Junior Gold Miners ETF - Learn about VanEck Vectors®
# Ad
# Junior Gold Miners ETF (GDXJ)
#
#                   www.vaneck.com
#
# Penny Stocks - Training Session Starts Soon!
# Ad
#
#               www.JasonBondPicks.com
# Learn 3 Easy Patterns That Made Jason Over $330,000 in 2016 Trading Part-Time!
#
# VFIAX Vanguard 500 Index Admiral Fund VFIAX Quote Price News
# Today's real-time VFIAX fund quote Vanguard 500 Index Admiral ticker symbol VFIAX price, snapshot, NAV, ratings, historical returns, news, risk measures, fees.
#
#                   morningstar.com/funds/XNAS/VFIAX/quote.html
#
# VFIAX : Summary for Vanguard 500 Index Fd Admiral S - Yahoo ...
# View the basic VFIAX stock chart on Yahoo Finance. Change the date range, chart type and compare Vanguard 500 Index Fd Admiral S against other companies.
#
#                   finance.yahoo.com/quote/VFIAX
#
# VFIAX Vanguard 500 Index Admiral XNAS:VFIAX Stock Quote Price ...
# ...

# %%
from  web_fetch_def import fetch_fnc
fetch_fnc("https://duckduckgo.com/html/?q=mpin+member+id+contract&ia=web",{"result__url","result__snippet","result__title"})
fetch_fnc("https://duckduckgo.com/html/?q=delegated+provider&ia=web",{"result__url","result__snippet","result__title"})
fetch_fnc("https://duckduckgo.com/html/?q=provider+network+healthcare&ia=web",{"result__url","result__snippet","result__title"})
fetch_fnc("https://duckduckgo.com/html/?q=emdeon+payer+list&ia=web",{"result__url","result__snippet","result__title"})
fetch_fnc("https://duckduckgo.com/html/?q=healthcare+provider+contract&ia=web",{"result__url","result__snippet","result__title"})
fetch_fnc("https://duckduckgo.com/html/?q=DRG+Diagnostic+Related+Groups&ia=web",{"result__url","result__snippet","result__title"})
fetch_fnc("https://duckduckgo.com/html/?q=EOB+Explanation+of+Benefits&ia=web",{"result__url","result__snippet","result__title"})
fetch_fnc("https://duckduckgo.com/html/?q=EOMB+Explanation+of+Medicare+Benefits&ia=web",{"result__url","result__snippet","result__title"})
fetch_fnc("https://duckduckgo.com/html/?q=EPD+Expanded+Provider+Database&ia=web",{"result__url","result__snippet","result__title"})
fetch_fnc("https://duckduckgo.com/html/?q=HCFA+Common+Procedural+Coding+System+HCPCS&ia=web",{"result__url","result__snippet","result__title"})
fetch_fnc("https://duckduckgo.com/html/?q=Health+Plan+Employer+Data+Information+Set+hedis&ia=web",{"result__url","result__snippet","result__title"})
fetch_fnc("https://duckduckgo.com/html/?q=HIPAA+Health+Insurance+Portability+Accountability+Act&ia=web",{"result__url","result__snippet","result__title"})
fetch_fnc("https://duckduckgo.com/html/?q=International+Classification+Diseases+ICD-9&ia=web",{"result__url","result__snippet","result__title"})
fetch_fnc("https://duckduckgo.com/html/?q=International+Classification+Diseases+ICD-10&ia=web",{"result__url","result__snippet","result__title"})
fetch_fnc("https://duckduckgo.com/html/?q=NCQR+National+Claim+Quality+Review&ia=web",{"result__url","result__snippet","result__title"})
fetch_fnc("https://duckduckgo.com/html/?q=NDB+Network+Database&ia=web",{"result__url","result__snippet","result__title"})
fetch_fnc("https://duckduckgo.com/html/?q=UR+Utilization+Review&ia=web",{"result__url","result__snippet","result__title"})
fetch_fnc("https://duckduckgo.com/html/?q=WebMD&ia=web",{"result__url","result__snippet","result__title"})
fetch_fnc("http://www.businessopportunity.com/",{"ListingCopy","ListingDesc","result__title"})
fetch_fnc("http://www.franchiseclique.com/industry/business-opportunities",{"col-xs-12 col-sm-3","minCashRequired","pricing-content"})
# Out:
# What is an MPIN? - Government Contracting Tips
# What is an MPIN? Posted on July 25 ... Enter your user ID and password, ... federal, government, government contract, government contractor, government contractors ...
#
#                   governmentcontractingtips.com/2013/07/25/what-is-an-mpin/
#
# Marketing Personal Identification Number (MPIN)
# Marketing Personal Identification Number (MPIN) ... Scroll to the bottom of the Points of Contact to view your MPIN. The Marketing Partner ID Number ...
#
#                   wingovernmentcontracts.com/marketing-personal-identification-number-...
#
# Frequently Asked Questions - Oregon Government Contract ...
# Frequently Asked Questions. ... Code is a five-character ID number used extensively within the federal government. ... What is an MPIN?
#
#                   gcap.org/home/gca/smartlist_5/frequently_asked_que...
#
# Grants.gov - E-Business Point of Contact Login
# ...

# %%
from  web_fetch_def import fetch_fnc
fetch_fnc("https://duckduckgo.com/html/?q=HIPAA+Health+Insurance+Portability+Accountability+Act&ia=web",{"result__url","result__snippet","result__title"})
# Out:
# Save on Books at Amazon - Low Prices on Millions of Books.
# Ad
# Low Prices on Millions of Books. Free 2-Day Shipping w/ Amazon Prime.
#
#                   Amazon.com/Books
#
# Health Insurance Portability and Accountability Act (HIPAA)
# Introduction As passed by the United States Congress, the Health Insurance Portability and Accountability Act of 1996 (HIPAA) will institute administrative reforms ...
#
#                   ihs.gov/hipaa/
#
# Health Insurance Portability and Accountability Act - Wikipedia
# The Health Insurance Portability and Accountability Act of 1996 (HIPAA; Pub.L. 104-191, 110 Stat. 1936, enacted August 21, 1996) was enacted by the United States ...
#
#                   en.wikipedia.org/wiki/Health_Insurance_Portability_and_Acc...
#
# Summary of the HIPAA Privacy Rule | HHS.gov
# Summary of the HIPAA Privacy ... The Health Insurance Portability and Accountability Act of ... one of which is a health plan, the HIPAA regulations apply to the ...
#
# ...

# %%
from  web_fetch_def import fetch_fnc
fetch_fnc("https://duckduckgo.com/html/?q=International+Classification+Diseases+ICD-9&ia=web",{"result__url","result__snippet","result__title"})
fetch_fnc("https://duckduckgo.com/html/?q=International+Classification+Diseases+ICD-10&ia=web",{"result__url","result__snippet","result__title"})
fetch_fnc("https://duckduckgo.com/html/?q=NCQR+National+Claim+Quality+Review&ia=web",{"result__url","result__snippet","result__title"})
fetch_fnc("https://duckduckgo.com/html/?q=NDB+Network+Database&ia=web",{"result__url","result__snippet","result__title"})
fetch_fnc("https://duckduckgo.com/html/?q=UR+Utilization+Review&ia=web",{"result__url","result__snippet","result__title"})
fetch_fnc("https://duckduckgo.com/html/?q=WebMD&ia=web",{"result__url","result__snippet","result__title"})
# Out:
# ICD - ICD-9-CM - International Classification of Diseases ...
# The International Classification of Diseases, Ninth Revision, Clinical Modification (ICD-9-CM) is based on the World Health Organization's Ninth Revision ...
#
#                   cdc.gov/nchs/icd/icd9cm.htm
#
# ICD - ICD-9 - International Classification of Diseases, Ninth ...
# The International Classification of Diseases (ICD) is designed to promote international comparability in the collection, processing, classification, and presentation ...
#
#                   cdc.gov/nchs/icd/icd9.htm
#
# WHO | International Classification of Diseases
# The International Classification of Diseases (ICD) is the standard diagnostic tool for epidemiology, health management and clinical purposes. This includes the ...
#
#                   who.int/classifications/icd/en/
#
# International Statistical Classification of Diseases and ...
# ...

# %%
from  web_fetch_def import fetch_fnc
fetch_fnc("https://duckduckgo.com/html/?q=delegated+provider&ia=web",{"result__url","result__snippet","result__title"})
# Out:
# State and Federal Legislation Updates: Delegated Provider ...
# Recent state and federal legislation updates that may impact the function(s) for which an organization is delegated to perform on behalf of Humana.
#
#                   humana.com/provider/support/delegated-resources/
#
# Delegated Credentialing: How It Can Impact Your Revenue ...
# What is Delegated Credentialing? As health systems grow larger, more and more providers are being credentialed with insurance carriers under what is known as ...
#
#                   msochealth.com/delegated-credentialing-how-it-can-impact...
#
# Delegated Credentialing - eMDs
# Eliminate provider credentialing delays and replace the old enrollment model with delegation. Learn more about the delegated credentialing process with eMDs.
#
#                   e-mds.com/eliminate-credentialing-delays-delegated-...
#
# Delegated Provider Credentialing - symplr | compliance
# ...
