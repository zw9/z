# %% [markdown]
# system command
# ===========

# %%
# !pwd;export;alias
# !ls -l
# !df -h
# !du -h
# !cal
# !printenv
# Out:
# /Users/zzz/Dropbox/z
# export Apple_PubSub_Socket_Render="/private/tmp/com.apple.launchd.3MecAID1KO/Render"
# export CLICOLOR="1"
# export CONDA_DEFAULT_ENV="base"
# export CONDA_EXE="//anaconda3/bin/conda"
# export CONDA_PREFIX="//anaconda3"
# export CONDA_PROMPT_MODIFIER="(base) "
# export CONDA_PYTHON_EXE="//anaconda3/bin/python"
# export CONDA_ROOT="//anaconda3"
# export CONDA_SHLVL="1"
# export GIT_PAGER="cat"
# export HOME="/Users/zzz"
# export JPY_PARENT_PID="6430"
# export KERNEL_LAUNCH_TIMEOUT="40"
# export LANG="en_US.UTF-8"
# export LC_ALL="en_US.UTF-8"
# export LC_CTYPE="UTF-8"
# export LOGNAME="zzz"
# export MPLBACKEND="module://ipykernel.pylab.backend_inline"
# export OLDPWD
# export PAGER="cat"
# export PATH="//anaconda3/bin://anaconda3/condabin:/usr/bin:/bin:/usr/sbin:/sbin"
# export PWD="/Users/zzz/Dropbox/z"
# export SHELL="/bin/bash"
# export SHLVL="3"
# export SSH_AUTH_SOCK="/private/tmp/com.apple.launchd.azfjyZAS3k/Listeners"
# export TERM="xterm-color"
# ...
